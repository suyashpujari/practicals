# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 1: Load the Iris dataset
iris_df = pd.read_csv('iris.csv')

# %%
iris_df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Class Label
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Step 2: List down the features and their types
print("Features and their types:")
print(iris_df.info())
# Out:
# Features and their types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Class Label    150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
iris_df.drop('Id', axis=1, inplace=True)

# %%
# Step 3: Create a histogram for each feature
iris_df.hist(figsize=(10, 8))
plt.title("Histogram for each feature")
plt.show()

# %%
 #Step 4: Create a boxplot for each feature
iris_df.boxplot(figsize=(10, 6))
plt.title("Boxplot for each feature")
plt.show()

# %%
sns.boxplot(x='PetalLengthCm',y='Class Label', data=iris_df)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Class Label'>

# %%
sns.boxplot(x='SepalLengthCm',y='Class Label',data=iris_df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Class Label'>
